# %%
import os
import pandas as pd
import haversine

# %%
#model carbon footprint by route cluster
#lol i just want to have a go at clustering

# %%
import os
stop_dirs = os.listdir('/home/student/data/stops')
#print(stop_dirs)

# %%
print(os.listdir('/home/student/data/'))
#gtfs='/home/student/data/gtfs/'
# Out:
# ['rt_leavetimes_2017_I_DB.txt', '.ipynb_checkpoints', 'gtfs', 'cleanweather.csv', 'rt_leavetimes_2016_I_DB.txt', 'stopsmap.pickle', 'officialroutes.csv', 'rt_trips_2017_I_DB.txt', 'Untitled.ipynb', 'stops', 'routesplits', 'weatherData', 'rt_trips_2016_I_DB.txt', 'js']

# %%
#can i match shape id to trip id?

# %%
from dbanalysis import headers

# %%
hds=headers.get_route_headers()

# %%
hds
# Out:
# ['index',
#  'datasource',
#  'dayofservice',
#  'tripid',
#  'progrnumber',
#  'stoppointid',
#  'plannedtime_arr',
#  'plannedtime_dep',
#  'actualtime_arr',
#  'actualtime_dep',
#  'vehicleid',
#  'passengers',
#  'passengersin',
#  'passengersout',
#  'distance',
#  'suppressed',
#  'justificationid',
#  'lastupdate',
#  'note']

# %%
print(os.listdir('/home/student/ResearchPracticum/data/routesplits'))
# Out:
# ['41_4', '31_16', '17_18', '41X_115', '220_12', '4_12', '17_14', '41C_80', '27B_34', '142_12', '111_9', '220_15', '145_102', '111_8', '41B_53', '70_67', '47_137', '77A_29', '76A_28', '33_71', '7B_91', '29A_14', '185_56', '114_5', '41X_118', '40D_105', '27X_42', '111_10', '76A_29', '75_19', '84X_58', '29A_15', '70D_70', '32_57', '7D_120', '238_15', '68_68', '40_26', '32_58', '184_28', '83_27', '46A_65', '42_44', '7D_121', '118_3', '757_2', '40B_64', '25X_7', '39A_40', '84X_53', '14_12', '46A_72', '9_8', '145_105', '7A_86', '33B_60', '27_19', '31A_26', '17_11', '40_32', '151_18', '32X_76', '104_16', '130_10', '25B_276', '75_21', '185_63', '33_40', '84A_1', '69X_57', '33_44', '25A_273', '39A_43', '46A_68', '46A_73', '46A_67', '104_15', '63_25', '70_69', '83_21', '17A_15', '38B_40', '41_3', '40D_106', '40D_101', '17_13', '84X_59', '185_55', '37_14', '16C_28', '75_20', '68_73', '59_10', '66X_100', '46A_66', '27_18', '40_19', '66X_92', '66X_94', '185_51', '13_76', '142_10', '9_5', '70D_71'
# ...

# %%
df=pd.read_csv('/home/student/ResearchPracticum/data/routesplits/16C_27', names=hds)

# %%
df.shape
# Out:
# (1375, 19)

# %%
df.head()
# Out:
#     index datasource        dayofservice   tripid  progrnumber  stoppointid  \
# 0  171091         DB  17-JAN-17 00:00:00  4092733            1          215
# 1  171092         DB  17-JAN-17 00:00:00  4092733            2          216
# 2  171093         DB  17-JAN-17 00:00:00  4092733            3          236
# 3  171094         DB  17-JAN-17 00:00:00  4092733            4          217
# 4  171095         DB  17-JAN-17 00:00:00  4092733            5          218
#
#    plannedtime_arr  plannedtime_dep  actualtime_arr  actualtime_dep  \
# 0            28200            28200           28230           28230
# 1            28293            28293           28348           28348
# 2            28300            28300           28350           28350
# 3            28364            28364           28376           28376
# 4            28431            28431           28487           28512
#
#    vehicleid  passengers  passengersin  passengersout  distance  suppressed  \
# ...

# %%
df.sort_values(by=['vehicleid','tripid', 'dayofservice','actualtime_arr'])
# Out:
#        index datasource        dayofservice   tripid  progrnumber  \
# 933   733978         DB  30-JAN-17 00:00:00  4339373           13
# 934   733979         DB  30-JAN-17 00:00:00  4339373           18
# 935   733980         DB  30-JAN-17 00:00:00  4339373           22
# 214   545732         DB  20-FEB-17 00:00:00  4392790            1
# 215   545733         DB  20-FEB-17 00:00:00  4392790            2
# 216   545734         DB  20-FEB-17 00:00:00  4392790            3
# 217   545735         DB  20-FEB-17 00:00:00  4392790            5
# 218   545736         DB  20-FEB-17 00:00:00  4392790            6
# 219   545737         DB  20-FEB-17 00:00:00  4392790            7
# 220   545738         DB  20-FEB-17 00:00:00  4392790            8
# 221   545739         DB  20-FEB-17 00:00:00  4392790            9
# 984   526392         DB  20-FEB-17 00:00:00  4392790           10
# 222   545740         DB  20-FEB-17 00:00:00  4392790           11
# ...

# %%
df.drop('index',axis=1)
# Out:
#      datasource        dayofservice   tripid  progrnumber  stoppointid  \
# 0            DB  17-JAN-17 00:00:00  4092733            1          215
# 1            DB  17-JAN-17 00:00:00  4092733            2          216
# 2            DB  17-JAN-17 00:00:00  4092733            3          236
# 3            DB  17-JAN-17 00:00:00  4092733            4          217
# 4            DB  17-JAN-17 00:00:00  4092733            5          218
# 5            DB  17-JAN-17 00:00:00  4092733            6          219
# 6            DB  17-JAN-17 00:00:00  4092733            8         1642
# 7            DB  17-JAN-17 00:00:00  4092733            9          213
# 8            DB  17-JAN-17 00:00:00  4092733           10          214
# 9            DB  17-JAN-17 00:00:00  4092733           11         4432
# 10           DB  17-JAN-17 00:00:00  4092733           13           44
# 11           DB  17-JAN-17 00:00:00  4092733           14         7603
# ...

# %%
route_16C = ['16C_27']

# %%
import pandas as pd
from dbanalysis import route_tools
to_concat = []
for route in route_16C:
    to_concat.append(route_tools.get_munged_route_data(route))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-b1021c7e442e> in <module>()
#       3 to_concat = []
#       4 for route in route_16C:
# ----> 5     to_concat.append(route_tools.get_munged_route_data(route))
#
# ~/dbanalysis/dbanalysis/route_tools.py in get_munged_route_data(routename)
#     124
#     125     rn = routename.split('_')[0]
# --> 126     stops_mapped = map_stops_single_route(rn)
#     127     import dbanalysis.headers as hds
#     128     headers = hds.get_route_headers()
#
# ~/dbanalysis/dbanalysis/route_tools.py in map_stops_single_route(rn)
#      54     Maps stops in a route to the stops with which they share a connection
#      55     """
# ---> 56     route_dict = json.loads(open('/home/student/dbanalysis/trimmed_routes.json','r').read())[rn]
#      57     route_dict = [route[1:] for route in route_dict]
#      58     stops_mapped = {}
#
# ...

# %%
#great thanks for moving the files right O
