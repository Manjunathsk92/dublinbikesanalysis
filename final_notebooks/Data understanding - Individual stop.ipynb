# %%
from dbanalysis import stop_tools

# %%
df = stop_tools.random_stop_data()

# %%
from matplotlib import pyplot as plt

# %%
df.columns
# Out:
# Index(['index', 'dayofservice', 'tripid', 'plannedtime_arr_from',
#        'plannedtime_dep_from', 'actualtime_arr_from', 'actualtime_dep_from',
#        'plannedtime_arr_to', 'actualtime_arr_to', 'routeid', 'fromstop',
#        'tostop', 'traveltime', 'distance', 'speed', 'dt', 'date', 'day',
#        'month', 'hour', 'year', 'dewpt', 'msl', 'rain', 'rhum', 'temp',
#        'vappr', 'wetb'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.kdeplot(df['traveltime'])

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
d = df

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
#Travel time's only decent correlation is with the time of day, the speed (as it comes directly from travel time),
# And a small correlation with hour.
#Not particularly surprising.

# %%
for column in weather.columns:
    
    ax=weather.boxplot(column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-593882ff5cc0> in <module>()
# ----> 1 for column in weather.columns:
#       2
#       3     ax=weather.boxplot(column)
#       4
#
# NameError: name 'weather' is not defined

# %% [markdown]
# # 10 random travel time distributions

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['traveltime'])

# %% [markdown]
# # 10 random speed distributions

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %%
df = stop_tools.random_stop_data()
sns.kdeplot(df['speed'])

# %% [markdown]
# # I think this goes to show that we are trying to predict for a number of very, very different variables

# %% [markdown]
# # Scatter plots for a single stop

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','rain')

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','temp')

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','vappr')

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','rhum')

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','dewpt')

# %%
df = stop_tools.random_stop_data()
df.plot.scatter('traveltime','actualtime_arr_from')

# %%
array = []
for day in sorted(df['day'].unique()):
    temp = df[df['day']==day]
    for hour in sorted(temp['hour'].unique()):
        temp2=temp[temp['hour']==hour]
        array.append(temp2['traveltime'].mean())

# %%
plt.plot(array)

# %%
# Out:
# 398.71700908731725
