# %%
import pandas as pd
weather = pd.read_csv('/data/cleanweather.csv')

# %%
weather.describe()
# Out:
#               dewpt           msl          rain          rhum          temp  \
# count  17542.000000  17542.000000  17542.000000  17542.000000  17542.000000
# mean       7.394043   1014.502594      0.081798     82.167997     10.432020
# std        4.556254     11.524280      0.402621     12.492597      5.151213
# min       -5.700000    968.500000      0.000000     28.000000     -4.000000
# 25%        3.800000   1007.800000      0.000000     74.000000      6.800000
# 50%        7.800000   1015.800000      0.000000     85.000000     10.600000
# 75%       10.800000   1022.200000      0.000000     92.000000     14.100000
# max       19.500000   1041.700000     17.400000    100.000000     28.300000
#
#               vappr          wetb
# count  17542.000000  17542.000000
# mean      10.733645      8.958825
# std        3.281280      4.522056
# min        4.000000     -4.300000
# 25%        8.000000      5.600000
# 50%       10.600000      9.200000
# 75%       12.900000     12.400000
# ...

# %%
import seaborn as sns

# %%
sns.kdeplot(weather['rain'])

# %%
sns.kdeplot(weather['temp'])

# %%
sns.kdeplot(weather['dewpt'])

# %%
sns.kdeplot(weather['msl'])

# %%
sns.kdeplot(weather['rhum'])

# %%
sns.kdeplot(weather['vappr'])

# %%
sns.kdeplot(weather['wetb'])

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
d = weather

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
from matplotlib import pyplot as plt
import numpy as np
fig, l = plt.subplots(figsize=(10,  10))
weather.boxplot([col for col in weather.columns if col != 'date'], ax=l)
